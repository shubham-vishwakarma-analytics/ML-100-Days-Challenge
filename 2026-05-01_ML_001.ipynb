# %% [markdown]
# # Phase 1: ML Foundation (Day 1–20)
# ## Day 1: ML Basics — Practice: Identify regression/classification — Project: Marks Prediction

# %% [markdown]
# ### Machine Learning = Learning patterns from data to make predictions
#
# ## Types:
# * Regression → Output = Number (Marks, Salary)
# * Classification → Output = Category (Pass/Fail)

# %% [markdown]
# ### TASK 1 — Thinking

# %% [raw]
# # DataSet
#
# Hours   Marks
# 1       10
# 2       20
# 3       30
# 4       40
# 5       50
#
# 1. Type:
# 2. X (input):
# 3. y (output):
# 4. Model:
#
#
# ANS:
#
# 1. Type: Regression
# 2. X (input): Hours
# 3. y (output): Marks
# 4. Model: LinearRegression

# %% [markdown]
# ### TASK 1 — Coding

# %%
# Create Dataset

import pandas as pd

data = {
    "Hours": [1, 2, 3, 4, 5],
    "Marks": [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Hours  Marks
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %%
# Import Libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# spliting the data
x = df[['Hours']]
y = df['Marks']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Train Model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict([[6]])
y_pred
# Out:
# C:\DevTools\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.])

# %%
new_data = pd.DataFrame({"Hours": [7.5]})
y_pred = model.predict(new_data)
print(y_pred)
# Out:
# [75.]

# %%
# Day 1 - Linear Regression

## 📌 Project

# Predict marks based on study hours

new_data = pd.DataFrame({"Hours": [8]})
y_pred = model.predict(new_data)
print(y_pred)
# Out:
# [80.]
